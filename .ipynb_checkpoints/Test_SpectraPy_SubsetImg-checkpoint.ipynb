# %%
from spectral import *
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (20,10)

# %%
file = "D:\\Documents\\UPN 2019-2\\Tesis\\Data\\hypercube_01.hdr"

# %%
img = open_image(file)

# %%
img.shape
# Out:
# (1250, 1600, 150)

# %%
TRUE_COLOR = (80,69,57)
# TRUE_COLOR = (58,34,19)

# %%
view = imshow(img, bands=TRUE_COLOR)

# %%
# Seleccionamos la imagen recortada para abarcar solo la muestra y el rango de longitud de onda 400 - 1000 nm
img_subset = img.read_subimage(range(95,1150), range(95,1380), range(50,126))

# %%
view = imshow(img_subset,bands=(10,20,30),stretch=0.01,title="Imagen Hiperespectral reducida")

# %% [markdown]
# # K-means Clustering

# %%
(m, c) = kmeans(img_subset, 20, 30)
# Out:
# Initializing clusters along diagonal of N-dimensional bounding box.
# Iteration 1...  0.Iteration 1...1355646 pixels reassigned.
# Iteration 2...  0.Iteration 2...143272 pixels reassigned.
# Iteration 3...  0.Iteration 3...94129 pixels reassigned.
# Iteration 4...  0.Iteration 4...122495 pixels reassigned.
# Iteration 5...  0.Iteration 5...84104 pixels reassigned.
# Iteration 6...  0.Iteration 6...60374 pixels reassigned.
# Iteration 7...  0.Iteration 7...53452 pixels reassigned.
# Iteration 8...  0.Iteration 8...51445 pixels reassigned.
# Iteration 9...  0.Iteration 9...50058 pixels reassigned.
# Iteration 10...  0.0Iteration 10...48849 pixels reassigned.
# Iteration 11...  0.0Iteration 11...47594 pixels reassigned.
# Iteration 12...  0.0Iteration 12...46695 pixels reassigned.
# Iteration 13...  0.0Iteration 13...46074 pixels reassigned.
# Iteration 14...  0.0Iteration 14...44885 pixels reassigned.
# Iteration 15...  0.0Iteration 15...43907 pixels reassigned.
# Iteration 16...  0.0Iteration 16...43653 pixels reassigned.
# Iteration 17...  0.0Iteration 17...43769 pixels reassigned.
# Iteration 18...  0.0Iteration 18...43621 pixels reassigned.
# Iteration 19...  0.0Iteration 19...43968 pixels reassigned.
# Iteration 20...  0.0Iteration 20...43206 pixels reassigned.
# Iteration 21...  0.0Iteration 21...41316 pixels reassigned.
# Iteration 22...  0.0Iteration 22...38199 pixels reassigned.
# Iteration 23...  0.0Iteration 23...35585 pixels reassigned.
# Iteration 24...  0.0Iteration 24...33149 pixels reassigned.
# Iteration 25...  0.0Iteration 25...31061 pixels reassigned.
# Iteration 26...  0.0Iteration 26...29263 pixels reassigned.
# Iteration 27...  0.0Iteration 27...28166 pixels reassigned.
# Iteration 28...  0.0Iteration 28...27409 pixels reassigned.
# Iteration 29...  0.0Iteration 29...26824 pixels reassigned.
# Iteration 30...  0.0Iteration 30...25422 pixels reassigned.
# kmeans terminated with 20 clusters after 30 iterations.

# %%
plt.xlabel('Wavelenghth Band')
plt.ylabel('Reflectance')
for i in range(c.shape[0]):
    plt.plot(c[i])
plt.show()

# %%
view = imshow(img_subset, bands=(30,19,7),stretch=0.01, classes=m)
view.set_display_mode('overlay')
view.class_alpha = 0.5
view.show_data
# Out:
# <bound method ImageView.show_data of ImageView object:
#   Display bands       :  (30, 19, 7)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [0.09638039431117622, 0.2252945126045291]
#     G: [0.13379722883476775, 0.3487151315387902]
#     B: [0.1138985533785021, 0.4178721845815785]
# >

# %% [markdown]
# # Clasificación Supervisada

# %% [markdown]
# ## Datos de Entrenamiento

# %%
gt = img_subset[:,:,27]
v = imshow(classes=gt)

# %%
classes = create_training_classes(img_subset, gt)

# %% [markdown]
# ## Gaussian Maximum Likelihood Classification

# %%
gmlc = GaussianClassifier(classes)
# Out:
# Setting min samples to 76
#   Omitting class   0 : only 49 samples present
#   Omitting class   0 : only 61 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 30 samples present
#   Omitting class   0 : only 57 samples present
#   Omitting class   0 : only 53 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 21 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 36 samples present
#   Omitting class   0 : only 24 samples present
#   Omitting class   0 : only 20 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 73 samples present
#   Omitting class   0 : only 46 samples present
#   Omitting class   0 : only 62 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 21 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 61 samples present
#   Omitting class   0 : only 22 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 28 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 22 samples present
#   Omitting class   0 : only 14 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 17 samples present
#   Omitting class   0 : only 17 samples present
#   Omitting class   0 : only 60 samples present
#   Omitting class   0 : only 38 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 71 samples present
#   Omitting class   0 : only 50 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 38 samples present
#   Omitting class   0 : only 47 samples present
#   Omitting class   0 : only 35 samples present
#   Omitting class   0 : only 40 samples present
#   Omitting class   0 : only 20 samples present
#   Omitting class   0 : only 51 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 32 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 21 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 48 samples present
#   Omitting class   0 : only 45 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 21 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 43 samples present
#   Omitting class   0 : only 44 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 18 samples present
#   Omitting class   0 : only 73 samples present
#   Omitting class   0 : only 31 samples present
#   Omitting class   0 : only 40 samples present
#   Omitting class   0 : only 38 samples present
#   Omitting class   0 : only 52 samples present
#   Omitting class   0 : only 33 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 65 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 13 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 22 samples present
#   Omitting class   0 : only 68 samples present
#   Omitting class   0 : only 53 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 40 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 23 samples present
#   Omitting class   0 : only 36 samples present
#   Omitting class   0 : only 25 samples present
#   Omitting class   0 : only 28 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 71 samples present
#   Omitting class   0 : only 73 samples present
#   Omitting class   0 : only 34 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 64 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 33 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 41 samples present
#   Omitting class   0 : only 17 samples present
#   Omitting class   0 : only 65 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 48 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 75 samples present
#   Omitting class   0 : only 16 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 23 samples present
#   Omitting class   0 : only 19 samples present
#   Omitting class   0 : only 74 samples present
#   Omitting class   0 : only 67 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 42 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 60 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 48 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 48 samples present
#   Omitting class   0 : only 49 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 48 samples present
#   Omitting class   0 : only 64 samples present
#   Omitting class   0 : only 70 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 74 samples present
#   Omitting class   0 : only 59 samples present
#   Omitting class   0 : only 60 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 50 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 35 samples present
#   Omitting class   0 : only 52 samples present
#   Omitting class   0 : only 63 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 22 samples present
#   Omitting class   0 : only 39 samples present
#   Omitting class   0 : only 36 samples present
#   Omitting class   0 : only 28 samples present
#   Omitting class   0 : only 31 samples present
#   Omitting class   0 : only 37 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 67 samples present
#   Omitting class   0 : only 35 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 74 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 38 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 50 samples present
#   Omitting class   0 : only 53 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 57 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 61 samples present
#   Omitting class   0 : only 37 samples present
#   Omitting class   0 : only 45 samples present
#   Omitting class   0 : only 30 samples present
#   Omitting class   0 : only 26 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 63 samples present
#   Omitting class   0 : only 70 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 68 samples present
#   Omitting class   0 : only 48 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 13 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 66 samples present
#   Omitting class   0 : only 64 samples present
#   Omitting class   0 : only 65 samples present
#   Omitting class   0 : only 72 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 60 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 72 samples present
#   Omitting class   0 : only 44 samples present
#   Omitting class   0 : only 19 samples present
#   Omitting class   0 : only 17 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 67 samples present
#   Omitting class   0 : only 50 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 53 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 62 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 40 samples present
#   Omitting class   0 : only 38 samples present
#   Omitting class   0 : only 42 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 66 samples present
#   Omitting class   0 : only 67 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 71 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 16 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 51 samples present
#   Omitting class   0 : only 59 samples present
#   Omitting class   0 : only 60 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 64 samples present
#   Omitting class   0 : only 36 samples present
#   Omitting class   0 : only 38 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 18 samples present
#   Omitting class   0 : only 70 samples present
#   Omitting class   0 : only 33 samples present
#   Omitting class   0 : only 36 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 37 samples present
#   Omitting class   0 : only 68 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 66 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 70 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 49 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 62 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 51 samples present
#   Omitting class   0 : only 71 samples present
#   Omitting class   0 : only 33 samples present
#   Omitting class   0 : only 23 samples present
#   Omitting class   0 : only 33 samples present
#   Omitting class   0 : only 31 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 74 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 68 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 65 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 46 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 26 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 71 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 18 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 63 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 32 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 43 samples present
#   Omitting class   0 : only 55 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 13 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 14 samples present
#   Omitting class   0 : only 66 samples present
#   Omitting class   0 : only 52 samples present
#   Omitting class   0 : only 70 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 44 samples present
#   Omitting class   0 : only 48 samples present
#   Omitting class   0 : only 71 samples present
#   Omitting class   0 : only 22 samples present
#   Omitting class   0 : only 38 samples present
#   Omitting class   0 : only 36 samples present
#   Omitting class   0 : only 39 samples present
#   Omitting class   0 : only 37 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 75 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 60 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 74 samples present
#   Omitting class   0 : only 46 samples present
#   Omitting class   0 : only 16 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 46 samples present
#   Omitting class   0 : only 71 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 22 samples present
#   Omitting class   0 : only 30 samples present
#   Omitting class   0 : only 30 samples present
#   Omitting class   0 : only 25 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 61 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 44 samples present
#   Omitting class   0 : only 51 samples present
#   Omitting class   0 : only 25 samples present
#   Omitting class   0 : only 72 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 16 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 26 samples present
#   Omitting class   0 : only 51 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 62 samples present
#   Omitting class   0 : only 52 samples present
#   Omitting class   0 : only 57 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 46 samples present
#   Omitting class   0 : only 53 samples present
#   Omitting class   0 : only 51 samples present
#   Omitting class   0 : only 43 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 65 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 63 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 19 samples present
#   Omitting class   0 : only 13 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 66 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 52 samples present
#   Omitting class   0 : only 52 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 31 samples present
#   Omitting class   0 : only 17 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 47 samples present
#   Omitting class   0 : only 34 samples present
#   Omitting class   0 : only 41 samples present
#   Omitting class   0 : only 30 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 75 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 62 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 43 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 72 samples present
#   Omitting class   0 : only 75 samples present
#   Omitting class   0 : only 28 samples present
#   Omitting class   0 : only 21 samples present
#   Omitting class   0 : only 23 samples present
#   Omitting class   0 : only 23 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 75 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 59 samples present
#   Omitting class   0 : only 50 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 68 samples present
#   Omitting class   0 : only 57 samples present
#   Omitting class   0 : only 41 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 73 samples present
#   Omitting class   0 : only 20 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 21 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 50 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 50 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 29 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 74 samples present
#   Omitting class   0 : only 20 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 37 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 13 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 60 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 44 samples present
#   Omitting class   0 : only 57 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 23 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 40 samples present
#   Omitting class   0 : only 31 samples present
#   Omitting class   0 : only 47 samples present
#   Omitting class   0 : only 30 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 57 samples present
#   Omitting class   0 : only 61 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 48 samples present
#   Omitting class   0 : only 65 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 71 samples present
#   Omitting class   0 : only 67 samples present
#   Omitting class   0 : only 21 samples present
#   Omitting class   0 : only 33 samples present
#   Omitting class   0 : only 29 samples present
#   Omitting class   0 : only 26 samples present
#   Omitting class   0 : only 59 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 55 samples present
#   Omitting class   0 : only 42 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 16 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 52 samples present
#   Omitting class   0 : only 29 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 65 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 22 samples present
#   Omitting class   0 : only 21 samples present
#   Omitting class   0 : only 18 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 59 samples present
#   Omitting class   0 : only 55 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 44 samples present
#   Omitting class   0 : only 52 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 41 samples present
#   Omitting class   0 : only 44 samples present
#   Omitting class   0 : only 32 samples present
#   Omitting class   0 : only 42 samples present
#   Omitting class   0 : only 63 samples present
#   Omitting class   0 : only 75 samples present
#   Omitting class   0 : only 71 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 62 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 68 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 28 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 40 samples present
#   Omitting class   0 : only 38 samples present
#   Omitting class   0 : only 33 samples present
#   Omitting class   0 : only 34 samples present
#   Omitting class   0 : only 72 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 55 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 53 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 42 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 36 samples present
#   Omitting class   0 : only 20 samples present
#   Omitting class   0 : only 21 samples present
#   Omitting class   0 : only 20 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 62 samples present
#   Omitting class   0 : only 35 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 55 samples present
#   Omitting class   0 : only 60 samples present
#   Omitting class   0 : only 41 samples present
#   Omitting class   0 : only 36 samples present
#   Omitting class   0 : only 43 samples present
#   Omitting class   0 : only 35 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 73 samples present
#   Omitting class   0 : only 13 samples present
#   Omitting class   0 : only 19 samples present
#   Omitting class   0 : only 19 samples present
#   Omitting class   0 : only 18 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 67 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 52 samples present
#   Omitting class   0 : only 51 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 43 samples present
#   Omitting class   0 : only 37 samples present
#   Omitting class   0 : only 40 samples present
#   Omitting class   0 : only 31 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 68 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 72 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 67 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 37 samples present
#   Omitting class   0 : only 67 samples present
#   Omitting class   0 : only 38 samples present
#   Omitting class   0 : only 37 samples present
#   Omitting class   0 : only 30 samples present
#   Omitting class   0 : only 37 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 63 samples present
#   Omitting class   0 : only 55 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 70 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 48 samples present
#   Omitting class   0 : only 66 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 17 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 70 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 71 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 73 samples present
#   Omitting class   0 : only 27 samples present
#   Omitting class   0 : only 27 samples present
#   Omitting class   0 : only 21 samples present
#   Omitting class   0 : only 18 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 68 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 50 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 52 samples present
#   Omitting class   0 : only 36 samples present
#   Omitting class   0 : only 49 samples present
#   Omitting class   0 : only 49 samples present
#   Omitting class   0 : only 37 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 73 samples present
#   Omitting class   0 : only 67 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 14 samples present
#   Omitting class   0 : only 20 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 65 samples present
#   Omitting class   0 : only 68 samples present
#   Omitting class   0 : only 72 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 52 samples present
#   Omitting class   0 : only 59 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 49 samples present
#   Omitting class   0 : only 37 samples present
#   Omitting class   0 : only 39 samples present
#   Omitting class   0 : only 33 samples present
#   Omitting class   0 : only 67 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 13 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 72 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 28 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 46 samples present
#   Omitting class   0 : only 47 samples present
#   Omitting class   0 : only 38 samples present
#   Omitting class   0 : only 36 samples present
#   Omitting class   0 : only 64 samples present
#   Omitting class   0 : only 59 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 28 samples present
#   Omitting class   0 : only 19 samples present
#   Omitting class   0 : only 25 samples present
#   Omitting class   0 : only 20 samples present
#   Omitting class   0 : only 75 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 50 samples present
#   Omitting class   0 : only 55 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 75 samples present
#   Omitting class   0 : only 63 samples present
#   Omitting class   0 : only 49 samples present
#   Omitting class   0 : only 41 samples present
#   Omitting class   0 : only 52 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 38 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 62 samples present
#   Omitting class   0 : only 73 samples present
#   Omitting class   0 : only 70 samples present
#   Omitting class   0 : only 19 samples present
#   Omitting class   0 : only 21 samples present
#   Omitting class   0 : only 14 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 59 samples present
#   Omitting class   0 : only 66 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 68 samples present
#   Omitting class   0 : only 68 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 64 samples present
#   Omitting class   0 : only 48 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 74 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 71 samples present
#   Omitting class   0 : only 65 samples present
#   Omitting class   0 : only 70 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 13 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 52 samples present
#   Omitting class   0 : only 55 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 39 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 32 samples present
#   Omitting class   0 : only 24 samples present
#   Omitting class   0 : only 39 samples present
#   Omitting class   0 : only 32 samples present
#   Omitting class   0 : only 64 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 51 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 60 samples present
#   Omitting class   0 : only 64 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 16 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 36 samples present
#   Omitting class   0 : only 30 samples present
#   Omitting class   0 : only 16 samples present
#   Omitting class   0 : only 22 samples present
#   Omitting class   0 : only 63 samples present
#   Omitting class   0 : only 55 samples present
#   Omitting class   0 : only 35 samples present
#   Omitting class   0 : only 64 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 62 samples present
#   Omitting class   0 : only 59 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 13 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 37 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 50 samples present
#   Omitting class   0 : only 32 samples present
#   Omitting class   0 : only 45 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 74 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 17 samples present
#   Omitting class   0 : only 13 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 66 samples present
#   Omitting class   0 : only 50 samples present
#   Omitting class   0 : only 74 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 55 samples present
#   Omitting class   0 : only 62 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 72 samples present
#   Omitting class   0 : only 40 samples present
#   Omitting class   0 : only 31 samples present
#   Omitting class   0 : only 42 samples present
#   Omitting class   0 : only 37 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 57 samples present
#   Omitting class   0 : only 75 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 13 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 53 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 36 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 39 samples present
#   Omitting class   0 : only 26 samples present
#   Omitting class   0 : only 28 samples present
#   Omitting class   0 : only 23 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 48 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 41 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 53 samples present
#   Omitting class   0 : only 51 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 21 samples present
#   Omitting class   0 : only 23 samples present
#   Omitting class   0 : only 19 samples present
#   Omitting class   0 : only 28 samples present
#   Omitting class   0 : only 66 samples present
#   Omitting class   0 : only 67 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 63 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 51 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 42 samples present
#   Omitting class   0 : only 39 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 50 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 22 samples present
#   Omitting class   0 : only 14 samples present
#   Omitting class   0 : only 18 samples present
#   Omitting class   0 : only 16 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 31 samples present
#   Omitting class   0 : only 38 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 14 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 44 samples present
#   Omitting class   0 : only 45 samples present
#   Omitting class   0 : only 37 samples present
#   Omitting class   0 : only 40 samples present
#   Omitting class   0 : only 71 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 14 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 70 samples present
#   Omitting class   0 : only 74 samples present
#   Omitting class   0 : only 16 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 18 samples present
#   Omitting class   0 : only 56 samples present
#   Omitting class   0 : only 58 samples present
#   Omitting class   0 : only 74 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 50 samples present
#   Omitting class   0 : only 34 samples present
#   Omitting class   0 : only 29 samples present
#   Omitting class   0 : only 46 samples present
#   Omitting class   0 : only 64 samples present
#   Omitting class   0 : only 68 samples present
#   Omitting class   0 : only 14 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 18 samples present
#   Omitting class   0 : only 54 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 21 samples present
#   Omitting class   0 : only 48 samples present
#   Omitting class   0 : only 57 samples present
#   Omitting class   0 : only 20 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 6 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 22 samples present
#   Omitting class   0 : only 15 samples present
#   Omitting class   0 : only 30 samples present
#   Omitting class   0 : only 26 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 69 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 12 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 57 samples present
#   Omitting class   0 : only 45 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 31 samples present
#   Omitting class   0 : only 7 samples present
#   Omitting class   0 : only 52 samples present
#   Omitting class   0 : only 45 samples present
#   Omitting class   0 : only 46 samples present
#   Omitting class   0 : only 44 samples present
#   Omitting class   0 : only 21 samples present
#   Omitting class   0 : only 41 samples present
#   Omitting class   0 : only 71 samples present
#   Omitting class   0 : only 5 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 67 samples present
#   Omitting class   0 : only 11 samples present
#   Omitting class   0 : only 22 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 9 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 3 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 1 samples present
#   Omitting class   0 : only 20 samples present
#   Omitting class   0 : only 51 samples present
#   Omitting class   0 : only 44 samples present
#   Omitting class   0 : only 2 samples present
#   Omitting class   0 : only 10 samples present
#   Omitting class   0 : only 8 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 4 samples present
#   Omitting class   0 : only 17 samples present
#   Omitting class   0 : only 61 samples present
#   Omitting class   0 : only 75 samples present
#   Omitting class   0 : only 48 samples present
#   Omitting class   0 : only 41 samples present
#   Omitting class   0 : only 39 samples present
#   Omitting class   0 : only 44 samples present
#   Omitting class   0 : only 17 samples present
#   Omitting class   0 : only 1 samples present
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-20f3ffae9e17> in <module>
# ----> 1 gmlc = GaussianClassifier(classes)
#
# c:\virtualenvs\feature_selection\lib\site-packages\spectral\algorithms\classifiers.py in __init__(self, training_data, min_samples)
#     127             self.min_samples = None
#     128         if training_data:
# --> 129             self.train(training_data)
#     130
#     131     def train(self, training_data):
#
# c:\virtualenvs\feature_selection\lib\site-packages\spectral\algorithms\classifiers.py in train(self, training_data)
#     151         for cl in self.classes:
#     152             if not hasattr(cl, 'stats') or not cl.stats_valid():
# --> 153                 cl.calc_stats()
#     154
#     155     def classify_spectrum(self, x):
#
# c:\virtualenvs\feature_selection\lib\site-packages\spectral\algorithms\algorithms.py in calc_stats(self)
#     987         =============  ======================   ===================================
#     988         '''
# --> 989         self.stats = calc_stats(self.image, self.mask, self.index)
#     990         self.nbands = self.image.shape[-1]
#     991         self._stats_valid = True
#
# c:\virtualenvs\feature_selection\lib\site-packages\spectral\algorithms\algorithms.py in calc_stats(image, mask, index, allow_nan)
#     889     '''
#     890     from spectral.algorithms.spymath import has_nan, NaNValueError
# --> 891     (mean, cov, N) = mean_cov(image, mask, index)
#     892     if has_nan(mean) and not allow_nan:
#     893         raise NaNValueError('NaN values present in data.')
#
# c:\virtualenvs\feature_selection\lib\site-packages\spectral\algorithms\algorithms.py in mean_cov(image, mask, index)
#     241
#     242     if isinstance(image, np.ndarray):
# --> 243         X = image.astype(np.float64)
#     244         if X.ndim == 3:
#     245             X = image.reshape(-1, image.shape[-1]).T
#
# KeyboardInterrupt:

# %%
clmap = gmlc.classify_image(img_subset)
