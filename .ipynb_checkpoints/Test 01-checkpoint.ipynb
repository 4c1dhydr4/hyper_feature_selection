# %%
import pandas as pd
import matplotlib.pyplot as plt
from tools import get_data
import seaborn as sns
import numpy as np

# %% [markdown]
# # Test 01 de Selección de Variables

# %% [markdown]
# * Tamaño de Muestra: 300 millones de datos
# * N° de Bandas: 150
# * N° de ROIs: 6

# %% [markdown]
# Definiciones:
#  * Rango en el nivel de la Calidad: 1 - 5, donde 1 es alta calidad y 5 es baja calidad.
#     * ROI B: Zona totalmente blanca.
#     * ROI A y F: Zona con partes cuarteadas blancas.
#     * ROI D: Zona parcialmente clara.
#     * ROI C: Zona parcialmente obscura.
#     * ROI E: Zona obscura.
#  * Para efectos de la presente experimentación, asumiremos que la calidad alta del alimento se determina por una zona totalmente blanca y la calidad baja se determina por una zona tptalmente obscura.

# %%
path = "D:\\Documentos\\LUIS AUGUSTO\\UPN 2019-2\\Tesis\\Data\\test_01\\rois\\"
# path = "D:\\Documents\\UPN 2019-2\\Tesis\\Data\\test_01\\rois\\"

# %% [markdown]
# ### Carga de Datos y Filtrado Inicial para datos entre la longitud de onda 400 y la banda 1000 (Bandas 49 - 124)

# %% [markdown]
# #### ROI A

# %%
A = get_data(path + 'A.roi.txt')
A.shape
# Out:
# (33992, 76)

# %% [markdown]
# #### ROI B

# %%
B = get_data(path + 'B.roi.txt')
B.shape
# Out:
# (36544, 76)

# %% [markdown]
# #### ROI C

# %%
C = get_data(path + 'C.roi.txt')
C.shape
# Out:
# (8244, 76)

# %% [markdown]
# #### ROI D

# %%
D = get_data(path + 'D.roi.txt')
D.shape
# Out:
# (54925, 76)

# %% [markdown]
# #### ROI E

# %%
E = get_data(path + 'E.roi.txt')
E.shape
# Out:
# (17494, 76)

# %% [markdown]
# #### ROI F

# %%
F = get_data(path + 'F.roi.txt')
F.shape
# Out:
# (34617, 76)

# %% [markdown]
# # Selección de Variables

# %%
from sklearn.feature_selection import SelectKBest, chi2
plt.rcParams["figure.figsize"] = (20,10)

# %%
def to_str(arr):
    x = []
    for a in arr:
        a = str(int(a))
        x.append(a)
    return np.array(x)

# %% [markdown]
# #### Clasificamos el nivel de calidad en base a una escala de 0 a 100 con saltos de 25 unidades y las asignamos como salida esperada para cada ROI.

# %%
y_A = np.random.randint(37,62,size=A.shape[0])
y_B = np.random.randint(0,12,size=B.shape[0])
y_C = np.random.randint(12,37,size=C.shape[0])
y_D = np.random.randint(62,87,size=D.shape[0])
y_E = np.random.randint(87,100,size=E.shape[0])
y_F = np.random.randint(37,62,size=F.shape[0])

# %%
y_A = np.ones(A.shape[0]) + 49
y_B = np.ones(B.shape[0])
y_C = np.ones(C.shape[0]) + 74
y_D = np.ones(D.shape[0]) + 24
y_E = np.ones(E.shape[0]) + 99
y_F = np.ones(F.shape[0]) + 49

# %%
y_A = to_str(y_A)
y_B = to_str(y_B)
y_C = to_str(y_C)
y_D = to_str(y_D)
y_E = to_str(y_E)
y_F = to_str(y_F)

# %% [markdown]
# #### Realizamos la selección de variables mediante la Prueba Gamma en función a la función Chi-2 y el Ranking de Variables

# %%
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit_A = bestfeatures.fit_transform(A,y_A)
fit_B = bestfeatures.fit_transform(B,y_B)
fit_C = bestfeatures.fit_transform(C,y_C)
fit_D = bestfeatures.fit_transform(D,y_D)
fit_E = bestfeatures.fit_transform(E,y_E)
fit_F = bestfeatures.fit_transform(F,y_F)

# %% [markdown]
# #### De las 10 Bandas escogidas para cada ROI, 6 serán utilizadas para los modelos de entrenamiento y 4 para testear el modelo.

# %%
colors = ('b','g','r','c','m','y','#F23C00','#211663','#535353','#00E27C')

# %%
fig = plt.figure()

for x in range(0,10):
    plt.subplot(2, 5, x+1)
    plt.scatter(range(0,fit_A[:,x].shape[0]), fit_A[:,x], color=colors[x])
    plt.title('RIO A - Variable {}'.format(x+1))
plt.show()

# %%
plt.xlabel("Banda")
plt.ylabel("Reflectancia")
pd.DataFrame(fit_A).mean().plot(color="red",style='+-', title ='Promedio por Banda')

# %%
fig = plt.figure()

for x in range(0,10):
    plt.subplot(2, 5, x+1)
    plt.scatter(range(0,fit_B[:,x].shape[0]), fit_B[:,x], color=colors[x])
    plt.title('RIO B - Variable {}'.format(x+1))
plt.show()

# %%
pd.DataFrame(fit_A).describe()
# Out:
#                   0             1             2             3             4  \
# count  33992.000000  33992.000000  33992.000000  33992.000000  33992.000000
# mean    2523.860114   2898.298453   3180.699194   3373.197399   3550.009944
# std      942.192327   1007.887462   1024.607355   1001.723196    976.043158
# min     1004.000000   1179.000000   1398.000000   1616.000000   1759.000000
# 25%     1809.000000   2124.000000   2390.000000   2599.000000   2798.000000
# 50%     2253.000000   2622.000000   2909.000000   3116.000000   3306.000000
# 75%     3093.000000   3535.000000   3839.000000   4022.000000   4183.000000
# max     5635.000000   6233.000000   6458.000000   6548.000000   6658.000000
#
#                   5             6             7             8             9
# count  33992.000000  33992.000000  33992.000000  33992.000000  33992.000000
# mean    3687.173894   3714.492381   3708.999618   3789.877707   3858.729760
# std      948.603982    907.556042    867.407083    852.302494    838.818181
# min     1957.000000   1951.000000   2078.000000   2187.000000   2270.000000
# 25%     2955.000000   3018.000000   3043.000000   3136.000000   3215.000000
# 50%     3457.000000   3496.000000   3506.000000   3594.500000   3671.000000
# 75%     4299.250000   4299.000000   4266.250000   4334.000000   4395.000000
# max     6701.000000   6553.000000   6421.000000   6518.000000   6474.000000

# %%
fig = plt.figure()

for x in range(0,10):
    plt.subplot(2, 5, x+1)
    plt.scatter(range(0,fit_C[:,x].shape[0]), fit_C[:,x], color=colors[x])
    plt.title('RIO C - Variable {}'.format(x+1))
plt.show()

# %%
pd.DataFrame(fit_C).describe()
# Out:
#                  0            1            2            3            4  \
# count  8244.000000  8244.000000  8244.000000  8244.000000  8244.000000
# mean   1504.057375  1702.604076  1870.708758  2002.666788  2128.491388
# std     305.211170   316.754771   325.954946   327.986514   331.043781
# min     948.000000  1106.000000  1249.000000  1405.000000  1508.000000
# 25%    1280.000000  1470.000000  1629.000000  1758.000000  1881.000000
# 50%    1441.000000  1637.000000  1803.000000  1936.000000  2063.500000
# 75%    1680.000000  1889.250000  2067.250000  2200.000000  2329.000000
# max    3168.000000  3261.000000  3406.000000  3529.000000  3675.000000
#
#                  5            6            7            8            9
# count  8244.000000  8244.000000  8244.000000  8244.000000  8244.000000
# mean   2235.342067  2270.928190  2279.504973  2341.532872  2399.630034
# std     333.025757   327.195365   320.971731   322.340056   323.182476
# min    1562.000000  1633.000000  1634.000000  1701.000000  1759.000000
# 25%    1985.000000  2026.000000  2036.000000  2099.750000  2157.000000
# 50%    2174.000000  2214.000000  2224.000000  2287.500000  2344.000000
# 75%    2440.000000  2471.000000  2471.250000  2535.000000  2594.250000
# max    3783.000000  3751.000000  3768.000000  3903.000000  3860.000000

# %%
fig = plt.figure()

for x in range(0,10):
    plt.subplot(2, 5, x+1)
    plt.scatter(range(0,fit_D[:,x].shape[0]), fit_D[:,x], color=colors[x])
    plt.title('RIO D - Variable {}'.format(x+1))
plt.show()

# %%
pd.DataFrame(fit_D).describe()
# Out:
#                   0             1             2             3            4  \
# count  54925.000000  54925.000000  54925.000000  54925.000000  54925.00000
# mean    2188.219117   2511.323678   2768.855457   2945.837797   3100.92650
# std      629.241761    636.383888    640.327889    632.298409    627.66413
# min     1100.000000   1372.000000   1568.000000   1726.000000   1901.00000
# 25%     1760.000000   2073.000000   2325.000000   2508.000000   2667.00000
# 50%     2041.000000   2378.000000   2644.000000   2823.000000   2982.00000
# 75%     2443.000000   2792.000000   3064.000000   3244.000000   3395.00000
# max     7227.000000   7370.000000   7629.000000   7597.000000   7700.00000
#
#                   5             6             7             8             9
# count  54925.000000  54925.000000  54925.000000  54925.000000  54925.000000
# mean    3203.415731   3201.807010   3185.543851   3296.342722   3268.717451
# std      619.228813    597.986205    579.519634    576.497971    557.695697
# min     2020.000000   2051.000000   2094.000000   2229.000000   2226.000000
# 25%     2777.000000   2791.000000   2788.000000   2900.000000   2884.000000
# 50%     3083.000000   3081.000000   3065.000000   3170.000000   3145.000000
# 75%     3492.000000   3477.000000   3446.000000   3547.000000   3512.000000
# max     7874.000000   7735.000000   7962.000000   7985.000000   7856.000000

# %%
fig = plt.figure()

for x in range(0,10):
    plt.subplot(2, 5, x+1)
    plt.scatter(range(0,fit_E[:,x].shape[0]), fit_E[:,x], color=colors[x])
    plt.title('RIO E - Variable {}'.format(x+1))
plt.show()

# %%
pd.DataFrame(fit_E).describe()
# Out:
#                   0             1             2             3             4  \
# count  17494.000000  17494.000000  17494.000000  17494.000000  17494.000000
# mean    1527.435749   1690.210358   1811.429290   1918.681491   2008.459357
# std      262.343436    275.475978    279.780484    283.893784    285.457391
# min      984.000000   1106.000000   1217.000000   1317.000000   1391.000000
# 25%     1357.000000   1513.000000   1631.000000   1734.000000   1822.000000
# 50%     1491.000000   1650.000000   1767.000000   1869.000000   1957.000000
# 75%     1635.000000   1799.000000   1923.000000   2033.000000   2130.000000
# max     2864.000000   3090.000000   3147.000000   3298.000000   3352.000000
#
#                   5             6             7             8             9
# count  17494.000000  17494.000000  17494.000000  17494.000000  17494.000000
# mean    2039.566709   2057.354407   2124.340345   2191.660969   2208.685606
# std      281.107897    272.541100    274.165347    273.828095    259.701698
# min     1401.000000   1463.000000   1502.000000   1548.000000   1597.000000
# 25%     1855.000000   1878.000000   1943.000000   2010.000000   2038.000000
# 50%     1989.000000   2011.000000   2079.000000   2152.000000   2174.000000
# 75%     2162.000000   2178.000000   2246.000000   2317.000000   2328.000000
# max     3349.000000   3294.000000   3354.000000   3435.000000   3313.000000

# %%
fig = plt.figure()

for x in range(0,10):
    plt.subplot(2, 5, x+1)
    plt.scatter(range(0,fit_F[:,x].shape[0]), fit_F[:,x], color=colors[x])
    plt.title('RIO F - Variable {}'.format(x+1))
plt.show()

# %%
pd.DataFrame(fit_F).describe()
# Out:
#                   0             1             2             3             4  \
# count  34617.000000  34617.000000  34617.000000  34617.000000  34617.000000
# mean    1976.873241   2297.781639   2557.007973   2755.735910   2949.111708
# std      602.651007    647.368464    663.311436    653.945913    644.911730
# min     1098.000000   1363.000000   1600.000000   1766.000000   1975.000000
# 25%     1595.000000   1885.000000   2131.000000   2331.000000   2527.000000
# 50%     1791.000000   2094.000000   2349.000000   2552.000000   2751.000000
# 75%     2123.000000   2457.000000   2728.000000   2932.000000   3132.000000
# max     5146.000000   5486.000000   5710.000000   5929.000000   6061.000000
#
#                   5             6             7             8             9
# count  34617.000000  34617.000000  34617.000000  34617.000000  34617.000000
# mean    3096.044371   3142.049918   3165.289309   3262.609354   3337.445908
# std      631.045357    604.724481    580.936078    574.567831    567.476445
# min     2054.000000   2076.000000   2147.000000   2293.000000   2346.000000
# 25%     2679.000000   2738.000000   2774.000000   2875.000000   2952.000000
# 50%     2901.000000   2959.000000   2990.000000   3091.000000   3167.000000
# 75%     3280.000000   3325.000000   3346.000000   3446.000000   3524.000000
# max     6122.000000   6097.000000   6158.000000   6085.000000   6132.000000

# %% [markdown]
# # Modelo de Clasificación

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
from tools import get_subsets, get_Ysubset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-146-9ba172b3bf78> in <module>
# ----> 1 from tools import get_subsets, get_Ysubset
#
# ImportError: cannot import name 'get_Ysubset'

# %%
a_train, a_test = get_subsets(fit_A)
b_train, b_test = get_subsets(fit_B)
c_train, c_test = get_subsets(fit_C)
d_train, d_test = get_subsets(fit_D)
e_train, e_test = get_subsets(fit_E)
f_train, f_test = get_subsets(fit_F)

# %%
yA_train, yA_test = get_Ysubset(y_A)
yB_train, yB_test = get_Ysubset(y_B)
yC_train, yC_test = get_Ysubset(y_C)
yD_train, yD_test = get_Ysubset(y_D)
yE_train, yE_test = get_Ysubset(y_E)
yF_train, yF_test = get_Ysubset(y_F)

# %%
x = np.concatenate((a_train, b_train, c_train, d_train, e_train, f_train))
y = np.concatenate((yA_train, yB_train, yC_train, yD_train, yE_train, yF_train))

# %%
x = np.concatenate((fit_A, fit_B, fit_C, fit_D, fit_E, fit_F))
y = np.concatenate((y_A, y_B, y_C, y_D, y_E, y_F))

# %%
y.shape
# Out:
# (6000,)

# %%
x.shape
# Out:
# (6000, 5)

# %%
model = Sequential()

# %%
model.add(Dense(50, input_dim=5, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='poisson', metrics=['acc'])
model.fit(x,y, epochs=20)
# Out:
# Epoch 1/20
# 6000/6000 [==============================] - 0s 75us/step - loss: 3.6275 - acc: 0.0137
# Epoch 2/20
# 6000/6000 [==============================] - 0s 47us/step - loss: 1.3763 - acc: 0.0138
# Epoch 3/20
# 6000/6000 [==============================] - 0s 46us/step - loss: 1.2186 - acc: 0.0138
# Epoch 4/20
# 6000/6000 [==============================] - 0s 45us/step - loss: 1.1546 - acc: 0.0138
# Epoch 5/20
# 6000/6000 [==============================] - 0s 46us/step - loss: 1.1197 - acc: 0.0138
# Epoch 6/20
# 6000/6000 [==============================] - 0s 47us/step - loss: 1.0977 - acc: 0.0138
# Epoch 7/20
# 6000/6000 [==============================] - 0s 45us/step - loss: 1.0825 - acc: 0.0138
# Epoch 8/20
# 6000/6000 [==============================] - 0s 45us/step - loss: 1.0714 - acc: 0.0138
# Epoch 9/20
# 6000/6000 [==============================] - 0s 46us/step - loss: 1.0630 - acc: 0.0138
# Epoch 10/20
# 6000/6000 [==============================] - 0s 47us/step - loss: 1.0563 - acc: 0.0138
# Epoch 11/20
# 6000/6000 [==============================] - 0s 46us/step - loss: 1.0509 - acc: 0.0138
# Epoch 12/20
# 6000/6000 [==============================] - 0s 45us/step - loss: 1.0465 - acc: 0.0138
# Epoch 13/20
# 6000/6000 [==============================] - 0s 47us/step - loss: 1.0427 - acc: 0.0138
# Epoch 14/20
# 6000/6000 [==============================] - 0s 46us/step - loss: 1.0396 - acc: 0.0138
# Epoch 15/20
# 6000/6000 [==============================] - 0s 45us/step - loss: 1.0368 - acc: 0.0138
# Epoch 16/20
# 6000/6000 [==============================] - 0s 46us/step - loss: 1.0344 - acc: 0.0138
# Epoch 17/20
# 6000/6000 [==============================] - 0s 46us/step - loss: 1.0323 - acc: 0.0138
# Epoch 18/20
# 6000/6000 [==============================] - 0s 46us/step - loss: 1.0305 - acc: 0.0138
# Epoch 19/20
# 6000/6000 [==============================] - 0s 50us/step - loss: 1.0288 - acc: 0.0138 ETA: 0s - loss: 1.0294 - acc: 0.
# Epoch 20/20
# 6000/6000 [==============================] - 0s 47us/step - loss: 1.0274 - acc: 0.0138

# %%
X = np.concatenate((fit_A[0:100,5:10],fit_B[0:100,5:10],fit_C[0:100,5:10], fit_D[0:100,5:10], fit_E[0:100,5:10], fit_F[0:100,5:10]))
Y = np.concatenate((y_A[0:100], y_B[0:100], y_C[0:100], y_D[0:100], y_E[0:100], y_F[0:100]))
z = model.predict(X)
for i, j in zip(Y, z):
    print('{} => {}'.format(i,j))

# %%
# Out:
#                    0              1              2              3  \
# count  185816.000000  185816.000000  185816.000000  185816.000000
# mean     2775.746680    3133.135058    3386.771263    3542.632088
# std      1637.160254    1734.703932    1754.230377    1715.353745
# min       835.000000     984.000000    1106.000000    1217.000000
# 25%      1646.000000    1934.000000    2175.000000    2364.000000
# 50%      2069.500000    2406.000000    2674.000000    2867.000000
# 75%      3389.000000    3804.000000    4094.000000    4261.000000
# max      8180.000000    8726.000000    8962.000000    8968.000000
#
#                    4
# count  185816.000000
# mean     3681.440420
# std      1674.057952
# min      1317.000000
# 25%      2540.000000
# 50%      3043.000000
# 75%      4411.000000
# max      8939.000000
